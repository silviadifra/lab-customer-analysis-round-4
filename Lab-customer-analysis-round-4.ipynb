# %%
import numpy as np
import pandas as pd

# %%
file1 = pd.read_csv("files_for_lab/csv_files/marketing_customer_analysis.csv")
print(file1.shape)
# Out:
# (9134, 24)

# %%
display(file1.head(10))
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
# 5  OC83172      Oregon              8256.297800      Yes     Basic  Bachelor
# 6  XZ87318      Oregon              5380.898636      Yes     Basic   College
# 7  CF85061     Arizona              7216.100311       No   Premium    Master
# 8  DY87989      Oregon             24127.504020      Yes     Basic  Bachelor
# 9  BQ94931      Oregon              7388.178085       No  Extended   College
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# ...

# %%
print("Original file1")
display(file1.head(1))

cols = []
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower())
file1.columns = cols

print("Lowercase version file1")
display(file1.head(1))
# Out:
# Original file1
#   Customer       State  Customer Lifetime Value Response Coverage Education  \
# 0  BU79786  Washington              2763.519279       No    Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
#
#   Total Claim Amount Vehicle Class Vehicle Size
# 0         384.811147  Two-Door Car      Medsize
#
# [1 rows x 24 columns]
# Lowercase version file1
#   customer       state  customer lifetime value response coverage education  \
# 0  BU79786  Washington              2763.519279       No    Basic  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# ...

# %%
#Show dataframe info
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer lifetime value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective to date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location code                  9134 non-null   object
#  11  marital status                 9134 non-null   object
# ...

# %%
display(file1.isna().sum())
file1.isna()
# Out:
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# dtype: int64
#       customer  state  customer lifetime value  response  coverage  education  \
# ...

# %%
nulls_df = pd.DataFrame(round(file1.isna().sum()/len(file1),2)*100)
nulls_df = nulls_df.reset_index()
display(nulls_df)
# Out:
#                             index    0
# 0                        customer  0.0
# 1                           state  0.0
# 2         customer lifetime value  0.0
# 3                        response  0.0
# 4                        coverage  0.0
# 5                       education  0.0
# 6               effective to date  0.0
# 7                employmentstatus  0.0
# 8                          gender  0.0
# 9                          income  0.0
# 10                  location code  0.0
# 11                 marital status  0.0
# 12           monthly premium auto  0.0
# 13        months since last claim  0.0
# 14  months since policy inception  0.0
# 15      number of open complaints  0.0
# 16             number of policies  0.0
# 17                    policy type  0.0
# 18                         policy  0.0
# 19               renew offer type  0.0
# 20                  sales channel  0.0
# 21             total claim amount  0.0
# 22                  vehicle class  0.0
# ...

# %%
nulls_df.columns = ['header_name', 'percent_nulls']
display(nulls_df.head(10))
# Out:
#                header_name  percent_nulls
# 0                 customer            0.0
# 1                    state            0.0
# 2  customer lifetime value            0.0
# 3                 response            0.0
# 4                 coverage            0.0
# 5                education            0.0
# 6        effective to date            0.0
# 7         employmentstatus            0.0
# 8                   gender            0.0
# 9                   income            0.0

# %%
display(file1.head(2))
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
#
#   months since policy inception number of open complaints  number of policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
#
#       policy type        policy  renew offer type  sales channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
#
#   total claim amount  vehicle class vehicle size
# 0         384.811147   Two-Door Car      Medsize
# ...

# %%
print(file1.shape)
# Out:
# (9134, 24)

# %%
#Datetime format - Extract the months from the dataset and store in a separate column. 
#Then filter the data to show only the information for the first quarter , ie. January, February and March. 
#Hint: If data from March does not exist, consider only January and February.

print(file1.dtypes)
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim            int64
# months since policy inception      int64
# number of open complaints          int64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
file1['effective to date'] = pd.to_datetime(file1['effective to date'], errors='coerce')
display(file1.head())
print(file1.dtypes)
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   months since policy inception number of open complaints  number of policies  \
# ...

# %%
pd.to_datetime(file1['effective to date']).dt.month
file1['months'] = pd.to_datetime(file1['effective to date']).dt.month
file1.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                         0                  1  Corporate Auto  Corporate L3
# ...

# %%
file1[(file1['months'].isin([1 , 2 , 3]))]
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  ...  \
# ...

# %%
#Describe DataFrame
file1.describe().T
# Out:
#                                 count          mean           std  \
# customer lifetime value        9134.0   8004.940475   6870.967608
# income                         9134.0  37657.380009  30379.904734
# monthly premium auto           9134.0     93.219291     34.407967
# months since last claim        9134.0     15.097000     10.073257
# months since policy inception  9134.0     48.064594     27.905991
# number of open complaints      9134.0      0.384388      0.910384
# number of policies             9134.0      2.966170      2.390182
# total claim amount             9134.0    434.088794    290.500092
# months                         9134.0      1.463762      0.498712
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  3994.251794   5780.182197
# income                            0.000000     0.000000  33889.500000
# monthly premium auto             61.000000    68.000000     83.000000
# ...

# %%
#Show a plot of the total number of responses.
import matplotlib.pyplot as plt
import seaborn as sns 

fig, ax = plt.subplots()
ax = sns.histplot(file1.response, color='tab:green')
plt.title('response')
plt.show()

# %%
#Show a plot of the response rate by the sales channel.

fig, ax = plt.subplots(figsize=(10,5))
sns.histplot(x='sales channel', hue='response', data=file1, multiple='dodge')
plt.show()

# %%
#Show a plot of the response rate by the total claim amount.
fig, ax = plt.subplots(figsize=(10,5))
sns.histplot(x='total claim amount', hue='response', data=file1, bins = 50)
plt.show()

# %%
#Show a plot of the response rate by the income.
fig, ax = plt.subplots(figsize=(10,5))
sns.histplot(x='income', hue='response', data=file1, bins = 50)
plt.show()

# %%
#Check the data types of the columns. 
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer lifetime value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective to date              9134 non-null   datetime64[ns]
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location code                  9134 non-null   object
#  11  marital status                 9134 non-null   object
# ...

# %%
#Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. 
#(You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
numerical=file1._get_numeric_data()

# %%
#or
numerical = file1.select_dtypes(include= np.number)

# %%
numerical.head()
# Out:
#    customer lifetime value  income  monthly premium auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months since last claim  months since policy inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number of open complaints  number of policies  total claim amount  months
# 0                          0                   1          384.811147       2
# 1                          0                   8         1131.464935       1
# ...

# %%
categorical = file1.select_dtypes(exclude= np.number)

# %%
categorical.head()
# Out:
#   customer       state response  coverage education effective to date  \
# 0  BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1  QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2  AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3  WW63253  California       No     Basic  Bachelor        2011-01-20
# 4  HB64268  Washington       No     Basic  Bachelor        2011-02-03
#
#   employmentstatus gender location code marital status     policy type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          policy renew offer type sales channel  vehicle class vehicle size
# ...

# %%
#Now we will try to check the normality of the numerical variables visually
#Use seaborn library to construct distribution plots for the numerical variables
fig, ax1 = plt.subplots(3,3,figsize=(10,10)) 
sns.histplot(x ='customer lifetime value',data = numerical ,bins = 20,color='tab:green', ax = ax1[0,0])
sns.histplot(x ='income',data = numerical ,bins = 20,color='tab:green', ax = ax1[0,1])
sns.histplot(x ='monthly premium auto',data = numerical ,bins = 20,color='tab:green', ax = ax1[0,2])
sns.histplot(x ='months since policy inception',data = numerical ,bins = 20,color='tab:green', ax = ax1[1,0])
sns.histplot(x ='number of open complaints',data = numerical ,bins = 20,color='tab:green', ax = ax1[1,1])
sns.histplot(x ='number of policies',data = numerical ,bins = 20,color='tab:green', ax = ax1[2,0])
sns.histplot(x ='total claim amount',data = numerical ,bins = 20,color='tab:green', ax = ax1[2,1])
sns.histplot(x ='months',data = numerical ,bins = 20,color='tab:green', ax = ax1[2,2])
plt.show()

# %%
sns.displot(x ='customer lifetime value',data = numerical , bins = 20,color='tab:green' )
plt.show()

# %%
#Use Matplotlib to construct histograms
numerical['months'].hist()
plt.show()
customer lifetime value

# %%
numerical['customer lifetime value'].hist()
# Out:
# <AxesSubplot:>

# %%
#Do the distributions for different numerical variables look like a normal distribution?
#no

# %%
#For the numerical variables, check the multicollinearity between the features. 
#Please note that we will use the column total_claim_amount later as the target variable.
#Drop one of the two features that show a high correlation between them (greater than 0.9). 
#Write code for both the correlation matrix and for seaborn heatmap. 
#If there is no pair of features that have a high correlation, then do not drop any features
correlations_matrix = numerical.corr()
correlations_matrix
# Out:
#                                customer lifetime value    income  \
# customer lifetime value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly premium auto                          0.396262 -0.016665
# months since last claim                       0.011517 -0.026715
# months since policy inception                 0.009418 -0.000875
# number of open complaints                    -0.036343  0.006408
# number of policies                            0.021955 -0.008656
# total claim amount                            0.226451 -0.355254
# months                                       -0.006096  0.000169
#
#                                monthly premium auto  months since last claim  \
# customer lifetime value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly premium auto                       1.000000                 0.005026
# ...

# %%
correlations_matrix = numerical.corr()
sns.heatmap(correlations_matrix, annot=True) # annot = True displays the correlation values, annot=False hides the correlation values
plt.show()
